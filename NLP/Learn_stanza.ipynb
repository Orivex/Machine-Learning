# %%
import stanza

# %%
nlp = stanza.Pipeline('de')

# %%
with open("data/Rapunzel.txt", "r") as f:
    doc = nlp(f.read())
for sentence in doc.sentences:
    print(sentence.dependencies)
# Out:
# [({
#   "id": 5,
#   "text": "Mann",
#   "lemma": "Mann",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 18,
#   "end_char": 22
# }, 'nsubj', {
#   "id": 1,
#   "text": "Es",
#   "lemma": "es",
#   "upos": "PRON",
#   "xpos": "PPER",
#   "feats": "Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs",
#   "head": 5,
#   "deprel": "nsubj",
#   "start_char": 0,
#   "end_char": 2
# }), ({
#   "id": 5,
#   "text": "Mann",
#   "lemma": "Mann",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Case=Nom|Gender=Masc|Number=Sing",
#   "head": 0,
#   "deprel": "root",
#   "start_char": 18,
#   "end_char": 22
# }, 'cop', {
#   "id": 2,
#   "text": "war",
#   "lemma": "sein",
#   "upos": "AUX",
#   "xpos": "VAFIN",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#   "head": 5,
#   "deprel": "cop",
#   "start_char": 3,
#   "end_char": 6
# }), ({
#   "id": 5,
# ...
