# %%
import matplotlib.pyplot as plt
import numpy as np

name = ["Pers1", "Pers2", "Pers3"]
iq = [120, 150, 5]

fig, ax = plt.subplots()

ax.plot([1.5, 1.5], [120, 150], color="g", lw=3, marker="o")
ax.text(1.55, 133, "Super-Intelligenz-Zone")

ax.set_title("Intelligenz (in IQ)")
ax.bar(name, iq)

plt.show()
